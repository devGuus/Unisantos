# %%
# Pacote de processamento de dados
import pandas as pd
import numpy as np

# Pacote de visualização de dados
import matplotlib.pyplot as plt

# %%
# Leitura do arquivo

arq = 'https://github.com/devGuus/Unisantos/raw/main/tde/Dados/importacoes-exportacoes-petroleo-2000-2023.xls'
arquivo1 = pd.read_excel(arq)

# Imprimindo arquivo completo

arquivo1
# Out:
#       ANO  MÊS   PRODUTO OPERAÇÃO COMERCIAL  IMPORTADO / EXPORTADO  \
# 0    2000  ABR  PETRÓLEO         EXPORTAÇÃO           0.000000e+00
# 1    2000  AGO  PETRÓLEO         EXPORTAÇÃO           0.000000e+00
# 2    2000  DEZ  PETRÓLEO         EXPORTAÇÃO           4.199504e+05
# 3    2000  FEV  PETRÓLEO         EXPORTAÇÃO           6.853779e-02
# 4    2000  JAN  PETRÓLEO         EXPORTAÇÃO           0.000000e+00
# ..    ...  ...       ...                ...                    ...
# 551  2022  SET  PETRÓLEO         IMPORTAÇÃO           1.630030e+06
# 552  2023  FEV  PETRÓLEO         EXPORTAÇÃO           2.872574e+06
# 553  2023  JAN  PETRÓLEO         EXPORTAÇÃO           7.183410e+06
# 554  2023  FEV  PETRÓLEO         IMPORTAÇÃO           1.415934e+06
# 555  2023  JAN  PETRÓLEO         IMPORTAÇÃO           1.785378e+06
#
#      DISPÊNDIO / RECEITA
# 0                      0
# 1                      0
# 2               59930153
# 3                     51
# 4                      0
# ...

# %%
# Para obter as (n) primeiras linhas do arquivo usamos head(n)

arquivo1.head(5)
# Out:
#     ANO  MÊS   PRODUTO OPERAÇÃO COMERCIAL  IMPORTADO / EXPORTADO
# 0  2000  ABR  PETRÓLEO         EXPORTAÇÃO               0.000000  \
# 1  2000  AGO  PETRÓLEO         EXPORTAÇÃO               0.000000
# 2  2000  DEZ  PETRÓLEO         EXPORTAÇÃO          419950.420200
# 3  2000  FEV  PETRÓLEO         EXPORTAÇÃO               0.068538
# 4  2000  JAN  PETRÓLEO         EXPORTAÇÃO               0.000000
#
#    DISPÊNDIO / RECEITA
# 0                    0
# 1                    0
# 2             59930153
# 3                   51
# 4                    0

# %%
# Para obter as (n) ultimas linhas do arquivo usamos tail(n)

arquivo1.tail(5)
# Out:
#       ANO  MÊS   PRODUTO OPERAÇÃO COMERCIAL  IMPORTADO / EXPORTADO
# 551  2022  SET  PETRÓLEO         IMPORTAÇÃO            1630029.820  \
# 552  2023  FEV  PETRÓLEO         EXPORTAÇÃO            2872573.620
# 553  2023  JAN  PETRÓLEO         EXPORTAÇÃO            7183410.070
# 554  2023  FEV  PETRÓLEO         IMPORTAÇÃO            1415933.786
# 555  2023  JAN  PETRÓLEO         IMPORTAÇÃO            1785377.756
#
#      DISPÊNDIO / RECEITA
# 551           1043765015
# 552           1199498348
# 553           3146824339
# 554            744182755
# 555           1013577742

# %%
# Imprime as informações gerais do arquivo:

arquivo1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 556 entries, 0 to 555
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ANO                    556 non-null    int64
#  1   MÊS                    556 non-null    object
#  2   PRODUTO                556 non-null    object
#  3   OPERAÇÃO COMERCIAL     556 non-null    object
#  4   IMPORTADO / EXPORTADO  556 non-null    float64
#  5   DISPÊNDIO / RECEITA    556 non-null    int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 26.2+ KB

# %%
# Descreve algumas estatísticas basiscas do arquivo:

arquivo1.describe()
# Out:
#                ANO  IMPORTADO / EXPORTADO  DISPÊNDIO / RECEITA
# count   556.000000           5.560000e+02         5.560000e+02
# mean   2011.086331           2.296623e+06         9.184161e+08
# std       6.692722           1.765387e+06         7.848334e+08
# min    2000.000000           0.000000e+00         0.000000e+00
# 25%    2005.000000           1.166569e+06         3.262072e+08
# 50%    2011.000000           1.817641e+06         7.242666e+08
# 75%    2017.000000           2.689730e+06         1.287026e+09
# max    2023.000000           9.705514e+06         4.569071e+09

# %%
# Mostra o número de valores únicos para cada coluna:

arquivo1.nunique()
# Out:
# ANO                       24
# MÊS                       12
# PRODUTO                    1
# OPERAÇÃO COMERCIAL         2
# IMPORTADO / EXPORTADO    551
# DISPÊNDIO / RECEITA      551
# dtype: int64

# %%
# Colocando o mês como primeira coluna e somando o numero de linhas e colunas
# Para usar uma coluna expecifica podemos usar (...).sum()['nomeDaColuna'])

pd.DataFrame(arquivo1.groupby(["MÊS", "ANO"]).sum())
# Out:
#                    PRODUTO    OPERAÇÃO COMERCIAL  IMPORTADO / EXPORTADO
# MÊS ANO
# ABR 2000  PETRÓLEOPETRÓLEO  EXPORTAÇÃOIMPORTAÇÃO           1.717434e+06  \
#     2001  PETRÓLEOPETRÓLEO  EXPORTAÇÃOIMPORTAÇÃO           2.168592e+06
#     2002  PETRÓLEOPETRÓLEO  EXPORTAÇÃOIMPORTAÇÃO           3.157112e+06
#     2003  PETRÓLEOPETRÓLEO  EXPORTAÇÃOIMPORTAÇÃO           2.746016e+06
#     2004  PETRÓLEOPETRÓLEO  EXPORTAÇÃOIMPORTAÇÃO           3.164088e+06
# ...                    ...                   ...                    ...
# SET 2018  PETRÓLEOPETRÓLEO  EXPORTAÇÃOIMPORTAÇÃO           7.121450e+06
#     2019  PETRÓLEOPETRÓLEO  EXPORTAÇÃOIMPORTAÇÃO           7.033625e+06
#     2020  PETRÓLEOPETRÓLEO  EXPORTAÇÃOIMPORTAÇÃO           6.012927e+06
#     2021  PETRÓLEOPETRÓLEO  EXPORTAÇÃOIMPORTAÇÃO           6.734117e+06
#     2022  PETRÓLEOPETRÓLEO  EXPORTAÇÃOIMPORTAÇÃO           8.135028e+06
#
#           DISPÊNDIO / RECEITA
# MÊS ANO
# ABR 2000            323484334
# ...

# %%
# Verifica os valores nulos de cada coluna.

print('Colunas:')
print(arquivo1.isnull().sum())
print()

# Número de linhas e colunas

num_lin, num_cols = arquivo1.shape
print(f"O conjunto de dados tem {num_lin} linhas e {num_cols} colunas.")
print()

# Nomes de cada coluna

column_names =arquivo1.columns.tolist()
print(f"Os nomes das colunas são: {column_names}")
print()

# Obter a média, mediana e devio do padrão

med_valor = arquivo1['IMPORTADO / EXPORTADO'].mean()
mediana_valor = arquivo1['IMPORTADO / EXPORTADO'].median()
desvio = arquivo1['IMPORTADO / EXPORTADO'].std()
print('A média é {}, a mediana é {} e o desvio de padrão é {}' .format(med_valor, mediana_valor, desvio))

# Função que agrupa os dados em uma coluna para obter estatísticas 

group_data = arquivo1.groupby('IMPORTADO / EXPORTADO').describe()
print(group_data)
# Out:
# Colunas:
# ANO                      0
# MÊS                      0
# PRODUTO                  0
# OPERAÇÃO COMERCIAL       0
# IMPORTADO / EXPORTADO    0
# DISPÊNDIO / RECEITA      0
# dtype: int64
#
# O conjunto de dados tem 556 linhas e 6 colunas.
#
# Os nomes das colunas são: ['ANO', 'MÊS', 'PRODUTO', 'OPERAÇÃO COMERCIAL', 'IMPORTADO / EXPORTADO', 'DISPÊNDIO / RECEITA']
#
# A média é 2296622.5714630834, a mediana é 1817641.3125 e o desvio de padrão é 1765387.001568184
#                         ANO
#                       count    mean  std     min     25%     50%     75%
# IMPORTADO / EXPORTADO
# 0.000000e+00            6.0  2000.0  0.0  2000.0  2000.0  2000.0  2000.0  \
# 6.853779e-02            1.0  2000.0  NaN  2000.0  2000.0  2000.0  2000.0
# 2.808926e+01            1.0  2000.0  NaN  2000.0  2000.0  2000.0  2000.0
# 6.282626e+04            1.0  2001.0  NaN  2001.0  2001.0  2001.0  2001.0
# 6.623137e+04            1.0  2000.0  NaN  2000.0  2000.0  2000.0  2000.0
# ...

# %%
# Pegando informação expecifica do arquivo

df_export = arquivo1[(arquivo1['OPERAÇÃO COMERCIAL'] == 'EXPORTAÇÃO') & (arquivo1['ANO'] == 2022)]

# Plota o gráfico de barras
plt.bar(df_export['MÊS'], df_export['DISPÊNDIO / RECEITA'])
plt.xlabel('Mês')
plt.ylabel('Quantidade Exportada (1000 m³)')
plt.title('Exportação no ano 2022')
plt.show()

# %%
# seleciona colunas para analise
colunas_analise = ['OPERAÇÃO COMERCIAL', 'IMPORTADO / EXPORTADO', 'DISPÊNDIO / RECEITA']
arquivo1_selecionado = arquivo1[colunas_analise]

# Exibir o DataFrame resultante
print(arquivo1_selecionado)
# Out:
#     OPERAÇÃO COMERCIAL  IMPORTADO / EXPORTADO  DISPÊNDIO / RECEITA
# 0           EXPORTAÇÃO           0.000000e+00                    0
# 1           EXPORTAÇÃO           0.000000e+00                    0
# 2           EXPORTAÇÃO           4.199504e+05             59930153
# 3           EXPORTAÇÃO           6.853779e-02                   51
# 4           EXPORTAÇÃO           0.000000e+00                    0
# ..                 ...                    ...                  ...
# 551         IMPORTAÇÃO           1.630030e+06           1043765015
# 552         EXPORTAÇÃO           2.872574e+06           1199498348
# 553         EXPORTAÇÃO           7.183410e+06           3146824339
# 554         IMPORTAÇÃO           1.415934e+06            744182755
# 555         IMPORTAÇÃO           1.785378e+06           1013577742
#
# [556 rows x 3 columns]

# %%
# filtra as linhas em que a coluna "OPERAÇÃO COMERCIAL" contém "IMPORTAÇÃO"
arquivo1_importacao = arquivo1[(arquivo1['OPERAÇÃO COMERCIAL'] == 'IMPORTAÇÃO')]

# filtra as linhas em que a coluna "OPERAÇÃO COMERCIAL" contém "EXPORTAÇÃO"
arquivo1_exportacao = arquivo1[(arquivo1['OPERAÇÃO COMERCIAL'] == 'EXPORTAÇÃO')]

# calcula o total de gastos para importação e exportação
total_importacao = arquivo1_importacao['DISPÊNDIO / RECEITA'].sum()
total_exportacao = arquivo1_exportacao['DISPÊNDIO / RECEITA'].sum()

# cria uma lista com os valores de gastos
valores = [total_importacao, total_exportacao]

# cria uma lista com os rótulos
rotulos = ['Importação', 'Exportação']

# plotar o gráfico de pizza
plt.pie(valores, labels=rotulos, autopct='%1.1f%%', startangle=90)

# adiciona título ao gráfico
plt.title('Proporção de Gastos entre Importação e Exportação')

# exibe o gráfico
plt.show()

# %%
# filtra as linhas em que OPERAÇÃO COMERCIAL é igual a IMPORTAÇÃO
arquivo1_importacao = arquivo1[arquivo1['OPERAÇÃO COMERCIAL'] == 'IMPORTAÇÃO']

# renomeia as colunas
arquivo1_importacao = arquivo1_importacao.rename(columns={'IMPORTADO / EXPORTADO': 'IMPORTAÇÃO', 'DISPÊNDIO / RECEITA': 'DISPÊNDIO'})

# remove a coluna OPERAÇÃO COMERCIAL
arquivo1_importacao = arquivo1_importacao.drop(columns='OPERAÇÃO COMERCIAL')

# remove o ano 2023
arquivo1_filtered = arquivo1_importacao[arquivo1_importacao['ANO'] < 2023]

# agrupa os dados por ano e soma o dispendio
dispendio_por_ano = arquivo1_filtered.groupby('ANO')['DISPÊNDIO'].sum()

# encontra o índice da maior e menor dispendio
maior_dispendio = dispendio_por_ano.argmax()
menor_dispendio = dispendio_por_ano.argmin()

# define as cores das barras
cores = ['r' if i == menor_dispendio else 'g' if i == maior_dispendio else 'b' for i in range(len(dispendio_por_ano))]

# plota o gráfico de barras
dispendio_por_ano.plot(kind='bar', color=cores, figsize=(10,5))

# define os títulos do gráfico e dos eixos
plt.title('Dispêndio por ano (com base nas Importações)')
plt.xlabel('Ano')
plt.ylabel('Dispêndio')

# exibe o gráfico
plt.show()

# %%
# filtra as linhas em que OPERAÇÃO COMERCIAL é igual a IMPORTAÇÃO
arquivo1_exportacao = arquivo1[arquivo1['OPERAÇÃO COMERCIAL'] == 'EXPORTAÇÃO']

# renomeia as colunas
arquivo1_exportacao = arquivo1_exportacao.rename(columns={'IMPORTADO / EXPORTADO': 'EXPORTAÇÃO', 'DISPÊNDIO / RECEITA': 'RECEITA'})

# remove a coluna OPERAÇÃO COMERCIAL
arquivo1_exportacao = arquivo1_exportacao.drop(columns='OPERAÇÃO COMERCIAL')

# remove o ano 2023
arquivo1_filtered = arquivo1_exportacao[arquivo1_exportacao['ANO'] < 2023]

# agrupa os dados por ano e soma o dispendio
receita_por_ano = arquivo1_filtered.groupby('ANO')['RECEITA'].sum()

# encontra o índice da maior e menor dispendio
maior_receita = receita_por_ano.argmax()
menor_receita = receita_por_ano.argmin()

# define as cores das barras
cores = ['r' if i == menor_receita else 'g' if i == maior_receita else 'b' for i in range(len(receita_por_ano))]

# plota o gráfico de barras
receita_por_ano.plot(kind='bar', color=cores, figsize=(10,5))

# define os títulos do gráfico e dos eixos
plt.title('Receita por ano (com base nas Exportações)')
plt.xlabel('Ano')
plt.ylabel('Receita')

# exibe o gráfico
plt.show()
